# %% [markdown]
# 1) Eliminar columnas no relevantes
# 2) Rellenar/Eliminar nulos
# 3) Eliminar duplicados
# 4) Revisar tipo de datos

# %%
import pandas as pd
import numpy as np

# %%
#Lectura de los datos
draftcombine_df=pd.read_csv(r"C:\Users\anala\OneDrive\Documentos\GitHub\Proyecto-Final\csv_originales\draft_combine_stats.csv")

#Revisión de las primeras filas
draftcombine_df.head()
# Out:
#    season  player_id first_name   last_name        player_name position  \
# 0    2001      12033       Adam  Allenspach    Adam Allenspach        C
# 1    2001       2240    Gilbert      Arenas     Gilbert Arenas       SG
# 2    2001       2220    Brandon   Armstrong  Brandon Armstrong       SG
# 3    2001       2203      Shane     Battier      Shane Battier    SF-PF
# 4    2001      12034     Cookie     Belcher     Cookie Belcher    SG-PG
#
#    height_wo_shoes height_wo_shoes_ft_in  height_w_shoes height_w_shoes_ft_in  \
# 0            83.50             6' 11.5''             NaN                  NaN
# 1            74.25             6' 2.25''             NaN                  NaN
# 2            75.50              6' 3.5''             NaN                  NaN
# 3            80.25             6' 8.25''             NaN                  NaN
# 4            75.00                6' 3''             NaN                  NaN
#
#    ...  spot_nba_break_right  spot_nba_corner_right  \
# ...

# %%
#Consulta de cantidad de datos con numpy (para confirmar registros y columnas especificadas)
np.shape(draftcombine_df)
# Out:
# (1202, 47)

# %%
#Revisión dataframe
draftcombine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1202 entries, 0 to 1201
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   season                        1202 non-null   int64
#  1   player_id                     1202 non-null   int64
#  2   first_name                    1202 non-null   object
#  3   last_name                     1202 non-null   object
#  4   player_name                   1202 non-null   object
#  5   position                      1197 non-null   object
#  6   height_wo_shoes               1153 non-null   float64
#  7   height_wo_shoes_ft_in         1153 non-null   object
#  8   height_w_shoes                1008 non-null   float64
#  9   height_w_shoes_ft_in          1008 non-null   object
#  10  weight                        1152 non-null   float64
#  11  wingspan                      1153 non-null   float64
# ...

# %%
#Filtro de fecha desde la season 2015
draftcombine_2015_df=draftcombine_df[draftcombine_df["season"]>2014]

# %%
#Revisión dataframe filtrado por fecha
draftcombine_2015_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 477 entries, 725 to 1201
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   season                        477 non-null    int64
#  1   player_id                     477 non-null    int64
#  2   first_name                    477 non-null    object
#  3   last_name                     477 non-null    object
#  4   player_name                   477 non-null    object
#  5   position                      474 non-null    object
#  6   height_wo_shoes               433 non-null    float64
#  7   height_wo_shoes_ft_in         433 non-null    object
#  8   height_w_shoes                366 non-null    float64
#  9   height_w_shoes_ft_in          366 non-null    object
#  10  weight                        432 non-null    float64
#  11  wingspan                      432 non-null    float64
# ...

# %%
# Verificar los nombres de las columnas
print("Columnas del DataFrame original:", draftcombine_2015_df.columns)
# Out:
# Columnas del DataFrame original: Index(['season', 'player_id', 'first_name', 'last_name', 'player_name',
#        'position', 'height_wo_shoes', 'height_wo_shoes_ft_in',
#        'height_w_shoes', 'height_w_shoes_ft_in', 'weight', 'wingspan',
#        'wingspan_ft_in', 'standing_reach', 'standing_reach_ft_in',
#        'body_fat_pct', 'hand_length', 'hand_width', 'standing_vertical_leap',
#        'max_vertical_leap', 'lane_agility_time', 'modified_lane_agility_time',
#        'three_quarter_sprint', 'bench_press', 'spot_fifteen_corner_left',
#        'spot_fifteen_break_left', 'spot_fifteen_top_key',
#        'spot_fifteen_break_right', 'spot_fifteen_corner_right',
#        'spot_college_corner_left', 'spot_college_break_left',
#        'spot_college_top_key', 'spot_college_break_right',
#        'spot_college_corner_right', 'spot_nba_corner_left',
#        'spot_nba_break_left', 'spot_nba_top_key', 'spot_nba_break_right',
# ...

# %% [markdown]
# Filtramos las columnas relevantes para el análisis
