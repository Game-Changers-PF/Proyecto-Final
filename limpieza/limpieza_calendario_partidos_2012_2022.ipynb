# %%
pip install nba_api
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import commonplayerinfo
import pandas as pd
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import leaguegamefinder, boxscoretraditionalv2
from nba_api.stats.endpoints import shotchartdetail
import time

# %%
from datetime import datetime

# %%
df_calendario = pd.read_csv("/Users/usuario1/Documents/GitHub/Proyecto-Final/csv_originales/calendario_partidos_2015_2022.csv")

df_calendario.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0      42015  1610612744               GSW  Golden State Warriors  41500407
# 1      42015  1610612739               CLE    Cleveland Cavaliers  41500407
# 2      42015  1610612739               CLE    Cleveland Cavaliers  41500406
# 3      42015  1610612744               GSW  Golden State Warriors  41500406
# 4      42015  1610612744               GSW  Golden State Warriors  41500405
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2016-06-19  GSW vs. CLE  L  239   89  ...   0.769     7    32   39   22
# 1  2016-06-19    CLE @ GSW  W  241   93  ...   0.840     9    39   48   17
# 2  2016-06-16  CLE vs. GSW  W  240  115  ...   0.781     8    37   45   24
# 3  2016-06-16    GSW @ CLE  L  238  101  ...   0.690     9    26   35   19
# 4  2016-06-13  GSW vs. CLE  L  242   97  ...   0.731    13    30   43   18
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# ...

# %%
# Convertir la columna GAME_DATE a tipo datetime si no está en ese formato
df_calendario['GAME_DATE'] = pd.to_datetime(df_calendario['GAME_DATE'])

# Filtrar por fechas específicas (por ejemplo, solo fechas después de '2023-01-01')
fecha_limite = datetime.strptime('2015-01-01', '%Y-%m-%d')
df_filtrado = df_calendario[df_calendario['GAME_DATE'] > fecha_limite]

df_filtrado.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0      42015  1610612744               GSW  Golden State Warriors  41500407
# 1      42015  1610612739               CLE    Cleveland Cavaliers  41500407
# 2      42015  1610612739               CLE    Cleveland Cavaliers  41500406
# 3      42015  1610612744               GSW  Golden State Warriors  41500406
# 4      42015  1610612744               GSW  Golden State Warriors  41500405
#
#    GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0 2016-06-19  GSW vs. CLE  L  239   89  ...   0.769     7    32   39   22
# 1 2016-06-19    CLE @ GSW  W  241   93  ...   0.840     9    39   48   17
# 2 2016-06-16  CLE vs. GSW  W  240  115  ...   0.781     8    37   45   24
# 3 2016-06-16    GSW @ CLE  L  238  101  ...   0.690     9    26   35   19
# 4 2016-06-13  GSW vs. CLE  L  242   97  ...   0.731    13    30   43   18
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# ...

# %%
# columnas que no aportan información relevante fueron eliminadas
columnas_no_relevantes = ['MATCHUP', 'MIN', 'WL', 'PLUS_MINUS']
df_procesado = df_filtrado.drop(columns=columnas_no_relevantes)

# %%
# Aquí es donde guardaremos el DataFrame procesado en un nuevo archivo CSV
ruta_nuevo_csv = '/Users/usuario1/Documents/GitHub/Proyecto-Final/csv_filtrados/cleaned_calendario_partidos_2015_2022.csv'

# Guardar el DataFrame procesado en un nuevo archivo CSV
df_procesado.to_csv(ruta_nuevo_csv, index=False)

print(f"Archivo guardado correctamente en {ruta_nuevo_csv}")
# Out:
# Archivo guardado correctamente en /Users/usuario1/Documents/GitHub/Proyecto-Final/csv_filtrados/cleaned_calendario_partidos_2015_2022.csv
